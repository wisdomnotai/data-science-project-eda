# %% [markdown]
# ## **Data Science Project** ,
# **Pandas Assesment** ,
# **Wisdom Alawode Olabowale**

# %%
#Importing necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Reading the data with pandas 

student_data = pd.read_csv("StudentsPerformance.csv")

# %%
#Displaying the last 10 rows

student_data.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
#Displaying the last 10 rows

student_data.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
#Checking the dataset overview

student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#checking the shape of the dataset

student_data.shape
# Out:
# (1000, 8)

# %%
#listing all columns in the  dataset

student_data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#Identifying if the column is numerical or categorical

for col in student_data.columns:
  if student_data[col].dtype in ["int64", "float64"]:
    print(f"{col} is numerical")
  else:
    print(f"{col} is categorical")
# Out:
# gender is categorical
# race/ethnicity is categorical
# parental level of education is categorical
# lunch is categorical
# test preparation course is categorical
# math score is numerical
# reading score is numerical
# writing score is numerical

# %%
#Displaying the descriptive statistics of the numerical columns

for col in student_data.columns:
  if student_data[col].dtype in ["int64", "float64"]:
    print(student_data[col].describe())
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64
# count    1000.000000
# mean       69.169000
# std        14.600192
# min        17.000000
# 25%        59.000000
# 50%        70.000000
# 75%        79.000000
# max       100.000000
# Name: reading score, dtype: float64
# count    1000.000000
# mean       68.054000
# std        15.195657
# min        10.000000
# 25%        57.750000
# 50%        69.000000
# 75%        79.000000
# max       100.000000
# Name: writing score, dtype: float64

# %%
#Checking for missing values on the dataset

student_data.isna()
print(f"{student_data.isna().sum()} missing values available")
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64 missing values available

# %%
#selecting all the students who completed the test preparation course

condition = student_data["test preparation course"] == "completed"
completed_students = condition
print(completed_students)
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999    False
# Name: test preparation course, Length: 1000, dtype: bool

# %%
#Finding all students who scored 70 and in maths

for col in student_data["math score"]:
  if col >= 70:
    print(col)
# Out:
# 72
# 90
# 76
# 71
# 88
# 78
# 88
# 74
# 73
# 70
# 97
# 81
# 74
# 75
# 82
# 77
# 88
# 71
# 82
# 79
# 80
# 72
# 73
# 76
# 71
# 73
# 71
# 79
# 78
# 79
# 85
# 98
# 87
# 70
# 77
# 99
# 84
# 75
# 78
# 79
# 91
# 88
# 83
# 87
# 72
# 82
# 89
# 87
# 75
# 74
# 70
# 71
# 76
# 88
# 88
# 73
# 100
# 77
# 70
# 82
# 75
# 81
# 96
# 72
# 94
# 79
# 81
# 71
# 97
# 80
# 77
# 76
# 77
# 78
# 74
# 82
# 81
# 74
# 80
# 87
# 84
# 83
# 87
# 86
# 72
# 88
# 76
# 92
# 83
# 80
# 84
# 73
# 80
# 75
# 85
# 89
# 71
# 80
# 78
# 70
# 79
# 99
# 76
# 88
# 71
# 88
# 83
# 85
# 73
# 73
# 70
# 81
# 97
# 88
# 77
# 76
# 86
# 78
# 71
# 90
# 81
# 80
# 74
# 99
# 73
# 71
# 77
# 83
# 75
# 71
# 82
# 82
# 71
# 90
# 83
# 76
# 79
# 72
# 77
# 75
# 87
# 80
# 85
# 73
# 84
# 74
# 82
# 80
# 85
# 71
# 80
# 87
# 79
# 73
# 73
# 77
# 76
# 85
# 74
# 88
# 82
# 87
# 70
# 84
# 71
# 84
# 71
# 74
# 82
# 86
# 73
# 75
# 75
# 70
# 89
# 78
# 73
# 79
# 86
# 81
# 100
# 79
# 100
# 72
# 71
# 77
# 75
# 84
# 72
# 77
# 91
# 83
# 90
# 71
# 76
# 80
# 76
# 73
# 70
# ...

# %%
#finding female students who scored atleast 65 in all 3 subjects

condition = (
    (student_data["gender"] == "female") & 
    (student_data["reading score"] >= 65) &
    (student_data["math score"] >= 65) &
    (student_data["writing score"] >= 65)
)

female_high_scorers = condition
print(female_high_scorers)
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998     True
# 999     True
# Length: 1000, dtype: bool

# %%
#finding the number of students with free/reduced lunch

free_lunch = student_data["lunch"] == "free/reduced"
number_of_students = free_lunch.sum()

print(number_of_students)
# Out:
# 355

# %%
#computing the average math score by gender

student_data.groupby("gender")["math score"].mean()
# Out:
# gender
# female    63.633205
# male      68.728216
# Name: math score, dtype: float64

# %%
#Computing average scores (math, reading, writing) by parental level of education

student_data.groupby("parental level of education")[["math score", "reading score", "writing score"]].mean()
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %%
#Comparing average scores of students with vs without test preparation

student_data.groupby("test preparation course")[["math score", "reading score", "writing score"]].mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673

# %%
# Plotting histogram for Math score

fig, axes = plt.subplots(1, 3, figsize=(18, 5))


axes[0].hist(student_data["math score"], bins=10, color='skyblue', edgecolor='black')
axes[0].set_title("Math Score Distribution")
axes[0].set_xlabel("Score")
axes[0].set_ylabel("Number of Students")
# Out:
# Text(0, 0.5, 'Number of Students')

# %%
# Plotting histogram for Reading Score

fig, axes = plt.subplots(1, 3, figsize=(18, 5))


axes[0].hist(student_data["reading score"], bins=10, color='skyblue', edgecolor='black')
axes[0].set_title("Reading Score Distribution")
axes[0].set_xlabel("Score")
axes[0].set_ylabel("Number of Students")
# Out:
# Text(0, 0.5, 'Number of Students')

# %%
# Plotting histogram for writing score

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].hist(student_data["writing score"], bins=10, color='skyblue', edgecolor='black')
axes[0].set_title("Writing Score Distribution")
axes[0].set_xlabel("Score")
axes[0].set_ylabel("Number of Students")
# Out:
# Text(0, 0.5, 'Number of Students')
